# %%
import pandas as pd
from IPython.display import clear_output

file = pd.ExcelFile("Market.xlsx")
print("Sheets available in the excel\n",file.sheet_names)
# Out:
# Sheets available in the excel
#  ['stats', '2018_Market', '2019_Market', '2020_Market', '2021_Market']

# %%
sheet = file.parse("stats")
print("type of sheet: ",type(sheet))
print("Content in the sheet:\n",sheet)
# Out:
# type of sheet:  <class 'pandas.core.frame.DataFrame'>
# Content in the sheet:
#      NAV_as_on     Amt  NAVperUnit  UnitsPurchased  Balance_Units  \
# 0  2018-05-30  2000.0     47.1800       42.390000       0.000000
# 1  2018-06-05  2000.0     47.1799       42.391000      42.391000
# 2  2018-07-05  2000.0     45.9715       43.505000      85.896000
# 3  2018-08-06  2000.0     48.5624       41.184000     127.080000
# 4  2018-09-05  2000.0     48.4393       41.289000     168.369000
# 5  2018-10-05  2000.0     42.9807       46.533000     214.902000
# 6  2018-11-05  2000.0     44.1242       45.327000     260.229000
# 7  2018-12-05  2000.0     45.0463       44.399000     304.628000
# 8  2019-01-07  2000.0     45.6408       43.820000     348.448000
# 9  2019-02-05  2000.0     45.1378       44.309000     392.757000
# 10 2019-03-05  2000.0     46.1033       43.381000     436.138000
# 11 2019-04-05  2000.0     48.7198       41.052000     477.190000
# 12 2019-05-06  2000.0     48.3019       41.406000     518.596000
# 13 2019-06-06  2000.0     50.1464       39.883222     558.479222
# 14 2019-07-10  2000.0     49.9317       40.054715     598.533937
# 15 2019-08-05  2000.0     46.4951       43.015285     641.549222
# 16 2019-09-05  2000.0     46.8816       42.660660     684.209882
# 17 2019-10-07  2000.0     48.3604       41.356151     725.566033
# 18 2019-11-05  2000.0     50.5742       39.545855     765.111888
# 19 2019-12-05  2000.0     50.4662       39.630485     804.742374
# 20 2020-01-06  2000.0     50.5446       39.569014     844.311388
# 21 2020-02-05  2000.0     52.1757       38.332020     882.643409
# 22 2020-03-05  2000.0     49.3596       40.518967     923.162376
# 23 2020-04-07  2000.0     37.7007       53.049413     976.211788
# 24 2020-05-05  2000.0     39.3188       50.866252    1027.078041
# 25 2020-06-05  2000.0     42.6070       46.940644    1074.018684
# 26 2020-07-06  1999.9     44.7370       44.703489    1118.722174
# 27 2020-08-05  1999.9     45.6331       43.825644    1162.547818
# 28 2020-09-07  1999.9     47.1178       42.444681    1204.992499
# 29 2020-10-05  1999.9     47.4611       42.137666    1247.130165
# 30 2020-11-05  1999.9     50.2520       39.797421    1286.927586
# 31 2020-12-07  1999.9     56.4622       35.420157    1322.347743
# 32 2021-01-05  1999.9     59.3334       33.706142    1356.053885
# 33 2021-02-08  1999.9     63.8593       31.317287    1387.371172
# 34 2021-03-08  1999.9     64.3436       31.081568    1418.452740
# 35 2021-04-06  1999.9     62.5797       31.957648    1450.410000
# 36 2021-05-05  1999.9     63.3015       31.593248    1482.003000
# 37 2021-06-09  1999.9     68.5185       29.187738    1511.190738
# 38 2021-07-07  1999.9     69.6762       28.702771    1539.893508
# 39 2021-08-05  1999.9     71.8455       27.836121    1567.729629
# 40 2021-09-10  1999.9     75.0804       26.636779    1594.367000
# 41 2021-10-05  1999.9     77.0583       25.953077    1620.320077
# 42 2021-11-08  1999.9     78.8887       25.351000    1645.671077
# 43 2021-12-06  1999.9     73.8839       27.068000    1672.739077
#
#     Investment_Value Current_value  GrowthRate  \
# 0             2000.0             -         NaN
# 1             2000.0       1958.61   97.930500
# 2             4000.0       3948.77   98.719250
# 3             6000.0       6171.31  102.855167
# 4             8000.0       8155.68  101.946000
# 5            10000.0       9236.64   92.366400
# 6            12000.0       11482.4   95.686667
# 7            14000.0      13722.36   98.016857
# 8            16000.0      15903.45   99.396563
# 9            18000.0      17728.19   98.489944
# 10           20000.0       20107.4  100.537000
# 11           22000.0      23248.32  105.674182
# 12           24000.0      25049.17  104.371542
# 13           26000.0      28005.71  107.714269
# 14           28000.0      29885.82  106.735071
# 15           30000.0      29828.88   99.429600
# 16           32000.0      32076.86  100.240188
# 17           34000.0      35088.66  103.201941
# 18           36000.0      38694.93  107.485917
# 19           38000.0      40612.27  106.874395
# 20           40000.0      42675.36  106.688400
# 21           42000.0      46052.52  109.648857
# 22           44000.0      45566.91  103.561159
# 23           46000.0      36803.84   80.008348
# 24           48000.0      40383.44   84.132167
# 25           50000.0      45760.68   91.521360
# 26           51999.9      50048.22   96.246762
# 27           53999.8      53050.62   98.242253
# 28           55999.7      56776.57  101.387275
# 29           57999.6       59190.6  102.053462
# 30           59999.5      64670.66  107.785332
# 31           61999.4      74662.62  120.424746
# 32           63999.3      80459.24  125.718938
# 33           65999.2      88596.48  134.238718
# 34           67999.1      91268.31  134.219879
# 35           69999.0      90766.22  129.667881
# 36           71998.9      93813.01  130.297838
# 37           73998.8     103544.54  139.927323
# 38           75998.7     107293.96  141.178678
# 39           77998.6     112634.35  144.405605
# 40           79998.5     119705.71  149.634943
# 41           81998.4      124859.1  152.270166
# 42           83998.3     129824.85  154.556521
# 43           85998.2     123588.48  143.710543
#
#                                     Scheme
# 0   L099G SBI Magnum Muilticap Fund-Reg Gr
# 1   L099G SBI Magnum Muilticap Fund-Reg Gr
# 2   L099G SBI Magnum Muilticap Fund-Reg Gr
# 3   L099G SBI Magnum Muilticap Fund-Reg Gr
# 4   L099G SBI Magnum Muilticap Fund-Reg Gr
# 5   L099G SBI Magnum Muilticap Fund-Reg Gr
# 6   L099G SBI Magnum Muilticap Fund-Reg Gr
# 7   L099G SBI Magnum Muilticap Fund-Reg Gr
# 8   L099G SBI Magnum Muilticap Fund-Reg Gr
# 9   L099G SBI Magnum Muilticap Fund-Reg Gr
# 10  L099G SBI Magnum Muilticap Fund-Reg Gr
# 11  L099G SBI Magnum Muilticap Fund-Reg Gr
# 12  L099G SBI Magnum Muilticap Fund-Reg Gr
# 13  L099G SBI Magnum Muilticap Fund-Reg Gr
# 14  L099G SBI Magnum Muilticap Fund-Reg Gr
# 15  L099G SBI Magnum Muilticap Fund-Reg Gr
# 16  L099G SBI Magnum Muilticap Fund-Reg Gr
# 17  L099G SBI Magnum Muilticap Fund-Reg Gr
# 18  L099G SBI Magnum Muilticap Fund-Reg Gr
# 19  L099G SBI Magnum Muilticap Fund-Reg Gr
# 20  L099G SBI Magnum Muilticap Fund-Reg Gr
# 21  L099G SBI Magnum Muilticap Fund-Reg Gr
# 22  L099G SBI Magnum Muilticap Fund-Reg Gr
# 23  L099G SBI Magnum Muilticap Fund-Reg Gr
# 24  L099G SBI Magnum Muilticap Fund-Reg Gr
# 25  L099G SBI Magnum Muilticap Fund-Reg Gr
# 26  L099G SBI Magnum Muilticap Fund-Reg Gr
# 27  L099G SBI Magnum Muilticap Fund-Reg Gr
# 28  L099G SBI Magnum Muilticap Fund-Reg Gr
# 29  L099G SBI Magnum Muilticap Fund-Reg Gr
# 30  L099G SBI Magnum Muilticap Fund-Reg Gr
# 31  L099G SBI Magnum Muilticap Fund-Reg Gr
# 32  L099G SBI Magnum Muilticap Fund-Reg Gr
# 33          L099G SBI Flexicap Fund-Reg Gr
# 34          L099G SBI Flexicap Fund-Reg Gr
# 35          L099G SBI Flexicap Fund-Reg Gr
# 36          L099G SBI Flexicap Fund-Reg Gr
# 37          L099G SBI Flexicap Fund-Reg Gr
# 38          L099G SBI Flexicap Fund-Reg Gr
# 39          L099G SBI Flexicap Fund-Reg Gr
# 40          L099G SBI Flexicap Fund-Reg Gr
# 41          L099G SBI Flexicap Fund-Reg Gr
# 42          L099G SBI Flexicap Fund-Reg Gr
# 43          L099G SBI Flexicap Fund-Reg Gr

# %% [markdown]
# #### There is no major difference between ExcelFile and read_excel funtion,
# https://stackoverflow.com/questions/26474693/excelfile-vs-read-excel-in-pandas

# %% [markdown]
# ##### Accessing specific columns from the excel

# %%
cols = [0, 2, 3, 4, 5, 6, 7]

df = pd.read_excel("Market.xlsx", usecols=cols)
print("'df' is of type: ", type(df))
print("\nPrinting specific columns: \n",df)
# Out:
# 'df' is of type:  <class 'pandas.core.frame.DataFrame'>
#
# Printing specific columns:
#      NAV_as_on  NAVperUnit  UnitsPurchased  Balance_Units  Investment_Value  \
# 0  2018-05-30     47.1800       42.390000       0.000000            2000.0
# 1  2018-06-05     47.1799       42.391000      42.391000            2000.0
# 2  2018-07-05     45.9715       43.505000      85.896000            4000.0
# 3  2018-08-06     48.5624       41.184000     127.080000            6000.0
# 4  2018-09-05     48.4393       41.289000     168.369000            8000.0
# 5  2018-10-05     42.9807       46.533000     214.902000           10000.0
# 6  2018-11-05     44.1242       45.327000     260.229000           12000.0
# 7  2018-12-05     45.0463       44.399000     304.628000           14000.0
# 8  2019-01-07     45.6408       43.820000     348.448000           16000.0
# 9  2019-02-05     45.1378       44.309000     392.757000           18000.0
# 10 2019-03-05     46.1033       43.381000     436.138000           20000.0
# 11 2019-04-05     48.7198       41.052000     477.190000           22000.0
# 12 2019-05-06     48.3019       41.406000     518.596000           24000.0
# 13 2019-06-06     50.1464       39.883222     558.479222           26000.0
# 14 2019-07-10     49.9317       40.054715     598.533937           28000.0
# 15 2019-08-05     46.4951       43.015285     641.549222           30000.0
# 16 2019-09-05     46.8816       42.660660     684.209882           32000.0
# 17 2019-10-07     48.3604       41.356151     725.566033           34000.0
# 18 2019-11-05     50.5742       39.545855     765.111888           36000.0
# 19 2019-12-05     50.4662       39.630485     804.742374           38000.0
# 20 2020-01-06     50.5446       39.569014     844.311388           40000.0
# 21 2020-02-05     52.1757       38.332020     882.643409           42000.0
# 22 2020-03-05     49.3596       40.518967     923.162376           44000.0
# 23 2020-04-07     37.7007       53.049413     976.211788           46000.0
# 24 2020-05-05     39.3188       50.866252    1027.078041           48000.0
# 25 2020-06-05     42.6070       46.940644    1074.018684           50000.0
# 26 2020-07-06     44.7370       44.703489    1118.722174           51999.9
# 27 2020-08-05     45.6331       43.825644    1162.547818           53999.8
# 28 2020-09-07     47.1178       42.444681    1204.992499           55999.7
# 29 2020-10-05     47.4611       42.137666    1247.130165           57999.6
# 30 2020-11-05     50.2520       39.797421    1286.927586           59999.5
# 31 2020-12-07     56.4622       35.420157    1322.347743           61999.4
# 32 2021-01-05     59.3334       33.706142    1356.053885           63999.3
# 33 2021-02-08     63.8593       31.317287    1387.371172           65999.2
# 34 2021-03-08     64.3436       31.081568    1418.452740           67999.1
# 35 2021-04-06     62.5797       31.957648    1450.410000           69999.0
# 36 2021-05-05     63.3015       31.593248    1482.003000           71998.9
# 37 2021-06-09     68.5185       29.187738    1511.190738           73998.8
# 38 2021-07-07     69.6762       28.702771    1539.893508           75998.7
# 39 2021-08-05     71.8455       27.836121    1567.729629           77998.6
# 40 2021-09-10     75.0804       26.636779    1594.367000           79998.5
# 41 2021-10-05     77.0583       25.953077    1620.320077           81998.4
# 42 2021-11-08     78.8887       25.351000    1645.671077           83998.3
# 43 2021-12-06     73.8839       27.068000    1672.739077           85998.2
#
#    Current_value  GrowthRate
# 0              -         NaN
# 1        1958.61   97.930500
# 2        3948.77   98.719250
# 3        6171.31  102.855167
# 4        8155.68  101.946000
# 5        9236.64   92.366400
# 6        11482.4   95.686667
# 7       13722.36   98.016857
# 8       15903.45   99.396563
# 9       17728.19   98.489944
# 10       20107.4  100.537000
# 11      23248.32  105.674182
# 12      25049.17  104.371542
# 13      28005.71  107.714269
# 14      29885.82  106.735071
# 15      29828.88   99.429600
# 16      32076.86  100.240188
# 17      35088.66  103.201941
# 18      38694.93  107.485917
# 19      40612.27  106.874395
# 20      42675.36  106.688400
# 21      46052.52  109.648857
# 22      45566.91  103.561159
# 23      36803.84   80.008348
# 24      40383.44   84.132167
# 25      45760.68   91.521360
# 26      50048.22   96.246762
# 27      53050.62   98.242253
# 28      56776.57  101.387275
# 29       59190.6  102.053462
# 30      64670.66  107.785332
# 31      74662.62  120.424746
# 32      80459.24  125.718938
# 33      88596.48  134.238718
# 34      91268.31  134.219879
# 35      90766.22  129.667881
# 36      93813.01  130.297838
# 37     103544.54  139.927323
# 38     107293.96  141.178678
# 39     112634.35  144.405605
# 40     119705.71  149.634943
# 41      124859.1  152.270166
# 42     129824.85  154.556521
# 43     123588.48  143.710543

# %% [markdown]
# ##### Code for pulling date, Units puschased when growth rate was > 100

# %%
cols = [0, 2, 7]
df = pd.read_excel("Market.xlsx", usecols=cols)

print("Data showing when Growth rate is above 100%:\n",df.loc[df["GrowthRate"] > 100])

print("\n Average rate of NAV:",df.NAVperUnit.mean())

print("\n Average of growth rate:",df.GrowthRate.mean())
# Out:
# Data showing when Growth rate is above 100%:
#      NAV_as_on  NAVperUnit  GrowthRate
# 3  2018-08-06     48.5624  102.855167
# 4  2018-09-05     48.4393  101.946000
# 10 2019-03-05     46.1033  100.537000
# 11 2019-04-05     48.7198  105.674182
# 12 2019-05-06     48.3019  104.371542
# 13 2019-06-06     50.1464  107.714269
# 14 2019-07-10     49.9317  106.735071
# 16 2019-09-05     46.8816  100.240188
# 17 2019-10-07     48.3604  103.201941
# 18 2019-11-05     50.5742  107.485917
# 19 2019-12-05     50.4662  106.874395
# 20 2020-01-06     50.5446  106.688400
# 21 2020-02-05     52.1757  109.648857
# 22 2020-03-05     49.3596  103.561159
# 28 2020-09-07     47.1178  101.387275
# 29 2020-10-05     47.4611  102.053462
# 30 2020-11-05     50.2520  107.785332
# 31 2020-12-07     56.4622  120.424746
# 32 2021-01-05     59.3334  125.718938
# 33 2021-02-08     63.8593  134.238718
# 34 2021-03-08     64.3436  134.219879
# 35 2021-04-06     62.5797  129.667881
# 36 2021-05-05     63.3015  130.297838
# 37 2021-06-09     68.5185  139.927323
# 38 2021-07-07     69.6762  141.178678
# 39 2021-08-05     71.8455  144.405605
# 40 2021-09-10     75.0804  149.634943
# 41 2021-10-05     77.0583  152.270166
# 42 2021-11-08     78.8887  154.556521
# 43 2021-12-06     73.8839  143.710543
#
#  Average rate of NAV: 53.13595681818181
#
#  Average of growth rate: 111.84182802712664

# %% [markdown]
# #### NOTE: Below code extract only month-year format from actual date 'NAV_as_on'

# %%
stats1 = file.parse("stats")

print("Data type of stats1 is: ",type(stats1))
stats1['MnthYr'] = pd.to_datetime(stats1['NAV_as_on']).dt.strftime('%m-%Y')

var = stats1.loc[stats1["GrowthRate"] > 100]["MnthYr"]
var2 = stats1.loc[stats1["GrowthRate"] > 100]["GrowthRate"]
print(var, var2)
# Out:
# Data type of stats1 is:  <class 'pandas.core.frame.DataFrame'>
# 3     08-2018
# 4     09-2018
# 10    03-2019
# 11    04-2019
# 12    05-2019
# 13    06-2019
# 14    07-2019
# 16    09-2019
# 17    10-2019
# 18    11-2019
# 19    12-2019
# 20    01-2020
# 21    02-2020
# 22    03-2020
# 28    09-2020
# 29    10-2020
# 30    11-2020
# 31    12-2020
# 32    01-2021
# 33    02-2021
# 34    03-2021
# 35    04-2021
# 36    05-2021
# 37    06-2021
# 38    07-2021
# 39    08-2021
# 40    09-2021
# 41    10-2021
# 42    11-2021
# 43    12-2021
# Name: MnthYr, dtype: object 3     102.855167
# 4     101.946000
# 10    100.537000
# 11    105.674182
# 12    104.371542
# 13    107.714269
# 14    106.735071
# 16    100.240188
# 17    103.201941
# 18    107.485917
# 19    106.874395
# 20    106.688400
# 21    109.648857
# 22    103.561159
# 28    101.387275
# 29    102.053462
# 30    107.785332
# 31    120.424746
# 32    125.718938
# 33    134.238718
# 34    134.219879
# 35    129.667881
# 36    130.297838
# 37    139.927323
# 38    141.178678
# 39    144.405605
# 40    149.634943
# 41    152.270166
# 42    154.556521
# 43    143.710543
# Name: GrowthRate, dtype: float64

# %% [markdown]
# #### Below code to draw graph for the  growth rate above 100

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=20,10 

plt.xticks(fontsize=13 )
plt.yticks(fontsize=15 )

plt.xlabel('month/year')
plt.ylabel('growth')
plt.title('Growth >100' )

plt.plot(var,var2)
plt.show()

# %% [markdown]
# #### Below code to draw graph for the complete growth chart

# %%
stats1 = file.parse("stats")

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=20,10

plt.xticks(fontsize=13)
plt.yticks(fontsize=15)

x1 = stats1['NAV_as_on']
y1 = stats1['GrowthRate']


plt.title('Complete growth chart')
plt.plot(x1,y1)
plt.show()

# %% [markdown]
# #### Below code is used to display growth rate for the year 2018

# %%
#### from 'stats' and '2018_market' sheets

stats1 = file.parse("2018_Market")

stats1 = pd.DataFrame(stats1)
start_date = '2018-01-01'
end_date ='2018-12-31'

mask = (stats1['NAV_as_on'] > start_date) & (stats1['NAV_as_on'] < end_date)

stats1 = stats1.loc[mask]

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=10,5


x1 = stats1['NAV_as_on']
y1 = stats1['GrowthRate']

plt.plot(x1,y1)
plt.bar(x1,y1)
plt.show()

# %% [markdown]
# #### Below code is used to display growth rate for the year 2018

# %%
#### from 'stats' and '2019_market' sheets

stats2 = file.parse("2019_Market")

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=15,5


x2 = stats2['NAV_as_on']
y2 = stats2['GrowthRate']

plt.plot(x2,y2)
plt.show()

# %% [markdown]
# ### Below code is used to display growth rate from the year 2018-to-21 years sheet-wise

# %%
stats1 = file.parse("2018_Market")
stats2 = file.parse("2019_Market")
stats3 = file.parse("2020_Market")
stats4 = file.parse("2021_Market")

import matplotlib.pyplot as plt

#plt.rcParams["figure.figsize"]=15,15 #this code  for customizing the size of the graph 

plt.xticks(fontsize=12 )#Used to set font size of the x-axis 
plt.yticks(fontsize=12 )#Used to set font size of the y-axis 


y1 = stats1['GrowthRate']

x2 = ["Jan","Feb","Mar","Apr","May", "Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
y2 = stats2['GrowthRate']


y3 = stats3['GrowthRate']

y4 = stats4['GrowthRate']


plt.plot(y1, label='2018', linestyle='-')  
plt.plot(x2,y2,label='2019', linestyle='--')
plt.plot(x2,y3,label='2020', linestyle='-.')
plt.plot(y4,label='2021', linestyle=':')
plt.legend()#Display the color line labels classifications
plt.show()
